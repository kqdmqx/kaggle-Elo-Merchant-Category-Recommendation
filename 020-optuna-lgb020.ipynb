# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # params

# %%
params = pd.read_csv("./models/optuna_result_lgb020.csv")

# %%
params.sort_values("value")
# Out:
#     Unnamed: 0  trial_id                state     value  \
# 87        86.0      86.0  TrialState.COMPLETE  3.646510
# 63        62.0      62.0  TrialState.COMPLETE  3.646664
# 11        10.0      10.0  TrialState.COMPLETE  3.647099
# 43        42.0      42.0  TrialState.COMPLETE  3.647236
# 74        73.0      73.0  TrialState.COMPLETE  3.647453
# 47        46.0      46.0  TrialState.COMPLETE  3.647634
# 84        83.0      83.0  TrialState.COMPLETE  3.647881
# 12        11.0      11.0  TrialState.COMPLETE  3.647952
# 68        67.0      67.0  TrialState.COMPLETE  3.648248
# 81        80.0      80.0  TrialState.COMPLETE  3.648291
# 27        26.0      26.0  TrialState.COMPLETE  3.648342
# 18        17.0      17.0  TrialState.COMPLETE  3.648451
# 45        44.0      44.0  TrialState.COMPLETE  3.648451
# 73        72.0      72.0  TrialState.COMPLETE  3.648523
# 15        14.0      14.0  TrialState.COMPLETE  3.648536
# 85        84.0      84.0  TrialState.COMPLETE  3.648698
# 71        70.0      70.0  TrialState.COMPLETE  3.648736
# 86        85.0      85.0  TrialState.COMPLETE  3.648755
# 61        60.0      60.0  TrialState.COMPLETE  3.648777
# 82        81.0      81.0  TrialState.COMPLETE  3.649030
# 23        22.0      22.0  TrialState.COMPLETE  3.649141
# 35        34.0      34.0  TrialState.COMPLETE  3.649172
# 31        30.0      30.0  TrialState.COMPLETE  3.649180
# 92        91.0      91.0  TrialState.COMPLETE  3.649315
# 55        54.0      54.0  TrialState.COMPLETE  3.649486
# 6          5.0       5.0  TrialState.COMPLETE  3.649575
# 58        57.0      57.0  TrialState.COMPLETE  3.649585
# 72        71.0      71.0  TrialState.COMPLETE  3.649639
# 67        66.0      66.0  TrialState.COMPLETE  3.649764
# 19        18.0      18.0  TrialState.COMPLETE  3.649907
# ..         ...       ...                  ...       ...
# 93        92.0      92.0  TrialState.COMPLETE  3.656486
# 75        74.0      74.0  TrialState.COMPLETE  3.656619
# 26        25.0      25.0  TrialState.COMPLETE  3.657260
# 4          3.0       3.0  TrialState.COMPLETE  3.658651
# 33        32.0      32.0  TrialState.COMPLETE  3.658886
# 42        41.0      41.0  TrialState.COMPLETE  3.659792
# 8          7.0       7.0  TrialState.COMPLETE  3.660072
# 36        35.0      35.0  TrialState.COMPLETE  3.664453
# 59        58.0      58.0  TrialState.COMPLETE  3.665620
# 2          1.0       1.0  TrialState.COMPLETE  3.671543
# 9          8.0       8.0  TrialState.COMPLETE  3.684791
# 3          2.0       2.0  TrialState.COMPLETE  3.690080
# 13        12.0      12.0  TrialState.COMPLETE  3.693814
# 16        15.0      15.0  TrialState.COMPLETE  3.695742
# 49        48.0      48.0  TrialState.COMPLETE  3.697703
# 1          0.0       0.0  TrialState.COMPLETE  3.700366
# 40        39.0      39.0  TrialState.COMPLETE  3.703036
# 65        64.0      64.0  TrialState.COMPLETE  3.705274
# 83        82.0      82.0  TrialState.COMPLETE  3.707895
# 45   4.177137181925869e-07    0.4495198408251555                   NaN
# 73                     NaN    0.9494590827285259   0.20750667070143958
# 15                     NaN     0.596741165024048                   NaN
# 85                     NaN    0.6849837136316452                   NaN
# 71                     NaN     0.610536429165322    0.8620065509713631
# 86                     NaN    0.9940816099420511    0.8834027325872778
# 61  1.7062437259872323e-07    0.6690440724668901                   NaN
# 82   0.0001182364964703907   0.41871923728732413                   NaN
# 23                     NaN    0.9100464639619097                   NaN
# 35                     NaN    0.9282642099873847                   NaN
# 31    0.028851411138646567    0.4677189188544339                   NaN
# 92  3.9289916405189465e-07  0.009140507676900889                   NaN
# 55                     NaN   0.23982631675697386  0.008014439110744315
# 6                      NaN    0.3884272028256494                   NaN
# 58                     NaN    0.7642543783273565                   NaN
# 72                     NaN     0.921170365601645                   NaN
# 67                     NaN    0.7865467110031872   0.15808339474099486
# 19                     NaN    0.9888926210730169                   NaN
# ..                     ...                   ...                   ...
# 93                     NaN    0.2639041758206465                   NaN
# 75                     NaN    0.8567957745308605    0.0648588509028939
# 26                     NaN    0.9691317747923163  0.024652626540367817
# 4   1.0237948351924076e-08    0.5612692335732811                   NaN
# 33                     NaN    0.7993112106274124                   NaN
# 42                     NaN    0.6220702157537972                   NaN
# 8                      NaN      0.72641883797001                   NaN
# 36                     NaN   0.03677591064416369    0.7158620848777945
# 59   0.0002445800770189063    0.3612899691461935                   NaN
# 2   1.2211354011322385e-05  0.012527104942107094                   NaN
# 9                      NaN   0.20188894509091668    0.7241423300759099
# 3                      NaN   0.04429152930112746    0.5646612834789355
# 13    0.001319192735243674    0.9909698776935321                   NaN
# 16                     NaN    0.8805121607345572                   NaN
# 49   0.0008685799267909059    0.8483127632131842                   NaN
# 1                      NaN   0.29887919970057536   0.11811661291785303
# 40                     NaN    0.8243781501958879    0.6986728087996871
# 65                     NaN    0.9900036383755714   0.43839772925548565
# 83                     NaN    0.8987208304068335   0.35812522632057586
# 70                     NaN    0.8199064013676367      0.38532649053406
# 98                     NaN    0.5126493582622634    0.6594044515609432
# 52                     NaN    0.6995084603907699   0.24826801775178653
# 29                     NaN    0.3822366659434342   0.32004414699802963
# 91                     NaN    0.3918808909490476    0.1812094050555595
# 80                     NaN    0.8198926783635845    0.5618697353304483
# 32                     NaN    0.1412713098719508   0.12888510928562813
# 7                      NaN     0.264765199897436    0.4552253002600064
# 89   1.899728591685059e-08    0.1624195002182498                   NaN
# 38   0.0024147776577059282   0.32762875921747947                   NaN
# 0                skip_drop             subsample              top_rate
#
# [101 rows x 20 columns]

# %%
best_params = pd.DataFrame()

best_params["param_name"] = params.loc[0]
best_params["best_dart"] = params.loc[87]
best_params["best_gbdt"] = params.loc[63]
best_params["best_goss"] =params.loc[11]

# %%
best_params
# Out:
#                          param_name                   best_dart  \
# Unnamed: 0                      NaN                          86
# trial_id                        NaN                          86
# state                           NaN         TrialState.COMPLETE
# value                           NaN                     3.64651
# datetime_start                  NaN  2019-02-18 01:30:20.007309
# datetime_complete               NaN  2019-02-18 01:32:21.227563
# params                     boosting                        dart
# params.1           colsample_bytree          0.7140058735819552
# params.2                  drop_rate       3.921198830433312e-06
# params.3                  max_depth                          11
# params.4           min_child_weight          28.517727948752466
# params.5           min_data_in_leaf                          53
# params.6             min_split_gain           4.660238646763835
# params.7                 num_leaves                          23
# params.8                 other_rate                         NaN
# params.9                  reg_alpha           49.03533562166284
# params.10                reg_lambda           36.15997267107921
# params.11                 skip_drop      4.0918621947407706e-07
# params.12                 subsample         0.47633499039596194
# params.13                  top_rate                         NaN
#
#                                     best_gbdt                   best_goss
# Unnamed: 0                                 62                          10
# trial_id                                   62                          10
# state                     TrialState.COMPLETE         TrialState.COMPLETE
# value                                 3.64666                      3.6471
# datetime_start     2019-02-18 00:56:17.656394  2019-02-17 23:35:34.043107
# datetime_complete  2019-02-18 00:58:07.682887  2019-02-17 23:36:45.697486
# params                                   goss                        gbdt
# params.1                   0.6741643096978434          0.2490103183630386
# params.2                                  NaN                         NaN
# params.3                                    6                           6
# params.4                   18.729849341798932          15.683032170854897
# params.5                                   35                          28
# params.6                    9.392597290081879           9.979192051521423
# params.7                                   81                          85
# params.8                   0.9276202680620784                         NaN
# params.9                    34.15461632987463           46.46404476987479
# params.10                  47.667145386029524           45.16884576268798
# params.11                                 NaN                         NaN
# params.12                  0.8906115834855368          0.9058813446425535
# params.13                 0.03515344717026679                         NaN

# %%
for name, value in zip(best_params.param_name, best_params.best_dart):
    if name == "boosting":
        name = "boosting_type"
        value = "'{}'".format(value)
    line = "lgb_params.{} = {}".format(name, value)
    if "nan" in line:
        continue
    print(line)
# Out:
# lgb_params.boosting_type = 'dart'
# lgb_params.colsample_bytree = 0.7140058735819552
# lgb_params.drop_rate = 3.921198830433312e-06
# lgb_params.max_depth = 11
# lgb_params.min_child_weight = 28.517727948752466
# lgb_params.min_data_in_leaf = 53
# lgb_params.min_split_gain = 4.660238646763835
# lgb_params.num_leaves = 23
# lgb_params.reg_alpha = 49.03533562166284
# lgb_params.reg_lambda = 36.15997267107921
# lgb_params.skip_drop = 4.0918621947407706e-07
# lgb_params.subsample = 0.47633499039596194

# %%
for name, value in zip(best_params.param_name, best_params.best_gbdt):
    if name == "boosting":
        name = "boosting_type"
        value = "'{}'".format(value)
    line = "lgb_params.{} = {}".format(name, value)
    if "nan" in line:
        continue
    print(line)
# Out:
# lgb_params.boosting_type = 'goss'
# lgb_params.colsample_bytree = 0.6741643096978434
# lgb_params.max_depth = 6
# lgb_params.min_child_weight = 18.729849341798932
# lgb_params.min_data_in_leaf = 35
# lgb_params.min_split_gain = 9.392597290081879
# lgb_params.num_leaves = 81
# lgb_params.other_rate = 0.9276202680620784
# lgb_params.reg_alpha = 34.15461632987463
# lgb_params.reg_lambda = 47.667145386029524
# lgb_params.subsample = 0.8906115834855368
# lgb_params.top_rate = 0.03515344717026679

# %%
for name, value in zip(best_params.param_name, best_params.best_goss):
    if name == "boosting":
        name = "boosting_type"
        value = "'{}'".format(value)
    line = "lgb_params.{} = {}".format(name, value)
    if "nan" in line:
        continue
    print(line)
# Out:
# lgb_params.boosting_type = 'gbdt'
# lgb_params.colsample_bytree = 0.2490103183630386
# lgb_params.max_depth = 6
# lgb_params.min_child_weight = 15.683032170854897
# lgb_params.min_data_in_leaf = 28
# lgb_params.min_split_gain = 9.979192051521423
# lgb_params.num_leaves = 85
# lgb_params.reg_alpha = 46.46404476987479
# lgb_params.reg_lambda = 45.16884576268798
# lgb_params.subsample = 0.9058813446425535

# %% [markdown]
# # blend

# %%
goss_pred = pd.read_csv("./data/submissions/lgb016_goss.csv")
gbdt_pred = pd.read_csv("./data/submissions/lgb016_gbdt.csv")
dart_pred = pd.read_csv("./data/submissions/lgb016_dart.csv")

# %%
all_preds = pd.DataFrame()

all_preds["goss"] = goss_pred.set_index("card_id").target
all_preds["gbdt"] = gbdt_pred.set_index("card_id").target
all_preds["dart"] = dart_pred.set_index("card_id").target

# %%
all_preds.corr()
# Out:
#           goss      gbdt      dart
# goss  1.000000  0.997427  0.994944
# gbdt  0.997427  1.000000  0.995059
# dart  0.994944  0.995059  1.000000

# %%
goss_pred = pd.read_csv("./data/submissions/lgb018_goss.csv")
gbdt_pred = pd.read_csv("./data/submissions/lgb018_gbdt.csv")
dart_pred = pd.read_csv("./data/submissions/lgb018_dart.csv")

# %%
all_preds = pd.DataFrame()

all_preds["goss"] = goss_pred.set_index("card_id").target
all_preds["gbdt"] = gbdt_pred.set_index("card_id").target
all_preds["dart"] = dart_pred.set_index("card_id").target

# %%
all_preds.corr()
# Out:
#           goss      gbdt      dart
# goss  1.000000  0.997391  0.995412
# gbdt  0.997391  1.000000  0.995626
# dart  0.995412  0.995626  1.000000

# %%
all_preds.mean(axis=1).reset_index(name="target").to_csv("./data/submissions/lgb018_blend.csv", index=False)

# %%
all_preds = pd.DataFrame()

goss_pred = pd.read_csv("./data/submissions/lgb016_goss.csv")
gbdt_pred = pd.read_csv("./data/submissions/lgb016_gbdt.csv")
dart_pred = pd.read_csv("./data/submissions/lgb016_dart.csv")
all_preds["goss016"] = goss_pred.set_index("card_id").target
all_preds["gbdt016"] = gbdt_pred.set_index("card_id").target
all_preds["dart016"] = dart_pred.set_index("card_id").target

goss_pred = pd.read_csv("./data/submissions/lgb018_goss.csv")
gbdt_pred = pd.read_csv("./data/submissions/lgb018_gbdt.csv")
dart_pred = pd.read_csv("./data/submissions/lgb018_dart.csv")
all_preds["goss018"] = goss_pred.set_index("card_id").target
all_preds["gbdt018"] = gbdt_pred.set_index("card_id").target
all_preds["dart018"] = dart_pred.set_index("card_id").target

blend010p = pd.read_csv("./data/submissions/blend010p.csv")
# all_preds["blend010"] = blend010p.set_index("card_id").target

# %%
blend010p["target"] = blend010p.target.values * 0.75 + all_preds.mean(axis=1).values * 0.25

# %%
all_preds.mean(axis=1).shape
# Out:
# (123623,)

# %%
# blend010p.to_csv("./data/submissions/blend018p.csv", index=False)
